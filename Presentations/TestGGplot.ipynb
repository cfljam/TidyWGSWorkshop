# %%
import pandas as pd
from ggplot import *
# %load_ext rpy2.ipython
from bokeh.charts import Scatter,Histogram, output_notebook, show
output_notebook()
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5635dade-115b-451e-a38b-3a340d575e35">Loading BokehJS ...</span>
#     </div>

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
ggplot(aes(x='carat',y='depth'),data=diamonds) + \
    geom_point(aes(color='price'))
# Out:
# <ggplot: (-9223372036552289269)>

# %%
# %%R
# library(data.table,quiet=TRUE)
# library(ggplot2,quiet=TRUE)
# library(dplyr,quiet=TRUE)
# diamonds %>%head
# Out:
# # A tibble: 6 × 10
#   carat       cut color clarity depth table price     x     y     z
#   <dbl>     <ord> <ord>   <ord> <dbl> <dbl> <int> <dbl> <dbl> <dbl>
# 1  0.23     Ideal     E     SI2  61.5    55   326  3.95  3.98  2.43
# 2  0.21   Premium     E     SI1  59.8    61   326  3.89  3.84  2.31
# 3  0.23      Good     E     VS1  56.9    65   327  4.05  4.07  2.31
# 4  0.29   Premium     I     VS2  62.4    58   334  4.20  4.23  2.63
# 5  0.31      Good     J     SI2  63.3    58   335  4.34  4.35  2.75
# 6  0.24 Very Good     J    VVS2  62.8    57   336  3.94  3.96  2.48

# %%
# %%R
# diamonds %>% ggplot(aes(x=carat,y=price)) + geom_point()

# %% [markdown]
# ### Try Bokeh

# %%
PIdf=pd.read_table('../CK_13_CHR1.Pi.gz',compression='gzip')

# %%
PIdf.head()
# Out:
#   CHROM  BIN_START  BIN_END  N_VARIANTS        PI
# 0  CHR1          1    10000         156  0.004791
# 1  CHR1      10001    20000         253  0.008446
# 2  CHR1      20001    30000         413  0.013647
# 3  CHR1      30001    40000         164  0.004879
# 4  CHR1      40001    50000         279  0.008922

# %%
h1=Histogram(PIdf,'PI')

# %%
show(h1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cadbf502-2e4a-4f88-9d75-efef08413fe3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cadbf502-2e4a-4f88-9d75-efef08413fe3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cadbf502-2e4a-4f88-9d75-efef08413fe3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cadbf502-2e4a-4f88-9d75-efef08413fe3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2b00d8ba-a3dd-4030-a7ef-7357c35059ea":{"roots":{"references":[{"attributes":{"data_source":{"id":"825d2ed7-f495-42ae-a2eb-0772462de40d","type":"ColumnDataSource"},"glyph":{"id":"a2841745-1be7-4506-9433-5692a0ec84ee","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"21e31bd3-770b-4cc0-9892-17a95e714283","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","height","y","color","line_color","label","fill_alpha","line_alpha","x"],"data":{"chart_index":["[0.000059, 0.001266]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[22.0],"label":["[0.000059, 0.001266]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.001206731971875],"x":["0.0006625"],"y":[11.0]}},"id":"caef5fdf-ad6d-48bd-bd97-ea85f798a914","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"06939d43-e36e-4fb7-b68b-a6e443bcaff4","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c32a826f-84da-49fb-a841-4d50ec7d0f94","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","height","y","color","line_color","label","fill_alpha","line_alpha","x"],"data":{"chart_index":["(0.035054, 0.036261]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.035054, 0.036261]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0012067319718749997],"x":["0.0356575"],"y":[0.0]}},"id":"637b3218-0e39-45db-8504-38fbdf87fbae","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"44198dfe-6d65-4bb9-b674-abb4cbe380de","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9bc1fe9c-3ded-44b3-bd01-330030e9ff28","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","height","y","color","line_color","label","fill_alpha","line_alpha","x"],"data":{"chart_index":["(0.029021, 0.030227]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(0.029021, 0.030227]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0012067319718749997],"x":["0.029624"],"y":[1.0]}},"id":"85b0d0f6-caf5-4c20-8351-04563798eb69","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"11ccda84-a543-4d19-be16-22f8b260b33c","type":"Rect"},{"attributes":{"data_source":{"id":"42676e6a-3350-479c-ac52-d26ff3bcc9e7","type":"ColumnDataSource"},"glyph":{"id":"fb754631-f94e-42bf-8ec9-a400830c3341","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c86fb4b4-bcac-47a3-a656-4f1d6cc80d16","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ce0358ce-2a1a-4837-9f6f-56a035ea5cec","type":"Rect"},{"attributes":{"data_source":{"id":"caef5fdf-ad6d-48bd-bd97-ea85f798a914","type":"ColumnDataSource"},"glyph":{"id":"2c347dee-a556-424c-8918-60dfd04b5dde","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"41461c4e-49a6-4212-ae10-cb10ba6ee707","type":" ...

# %%
tooltips=[
    ('N Variants','@N_VARIANTS'),
    ('Bin Start', '@BIN_START')
]
s1=Scatter(PIdf,'BIN_START','PI',
          title="Tajimas Pi, CHR1 ",tooltips=tooltips,height=300)

# %%
show(s1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="89868860-a595-40fa-b2de-b268e998a731"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("89868860-a595-40fa-b2de-b268e998a731");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("89868860-a595-40fa-b2de-b268e998a731");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '89868860-a595-40fa-b2de-b268e998a731' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f90d0715-7f90-4e4b-8a6a-187908f796f5":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"},"ticker":{"id":"0e7a773d-bb89-4526-af55-f1e5340d14cd","type":"BasicTicker"}},"id":"cb131644-9994-4f1e-9f6c-f0b582668c30","type":"Grid"},{"attributes":{"axis_label":"PI","formatter":{"id":"1bd5eccb-6848-445d-a481-2ab555450e2c","type":"BasicTickFormatter"},"plot":{"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"},"ticker":{"id":"0e7a773d-bb89-4526-af55-f1e5340d14cd","type":"BasicTicker"}},"id":"0312f7f8-b8c1-4b01-9057-b9c8f041fbaf","type":"LinearAxis"},{"attributes":{"data_source":{"id":"461ea45c-2df2-462c-a622-3b7a28d260fe","type":"ColumnDataSource"},"glyph":{"id":"051cbacf-3c46-4c06-a84b-e141d69620e9","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"17cf63b7-7cb9-4b17-b54c-353fa757b397","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"}},"id":"f0b37457-26a6-49aa-ba3b-95b2a55a0bc9","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"},"ticker":{"id":"8aaa8cd9-ea44-4723-8381-7034a139279f","type":"BasicTicker"}},"id":"19e6d571-e1ba-4690-9f60-d5eab61234a1","type":"Grid"},{"attributes":{"plot":null,"text":"Tajimas Pi, CHR1 "},"id":"768c5cdb-5baa-44c3-805b-d20b836db072","type":"Title"},{"attributes":{"overlay":{"id":"5300e380-f3b3-4a0a-9707-17b84fb8ea96","type":"BoxAnnotation"},"plot":{"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"}},"id":"d22377bf-cc57-4ba3-9564-dc81e8de38c5","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":0.04253604231,"start":-0.00380246541},"id":"9694e772-1053-4087-aa28-360ef74fe6a7","type":"Range1d"},{"attributes":{"below":[{"id":"ca47be34-8040-4b85-8b71-65ddd172dbd5","type":"LinearAxis"}],"css_classes":null,"height":300,"left":[{"id":"0312f7f8-b8c1-4b01-9057-b9c8f041fbaf","type":"LinearAxis"}],"renderers":[{"id":"5300e380-f3b3-4a0a-9707-17b84fb8ea96","type":"BoxAnnotation"},{"id":"17cf63b7-7cb9-4b17-b54c-353fa757b397","type":"GlyphRenderer"},{"id":"d58c34b1-dc84-4b5a-a7b4-dfe8312ca5fc","type":"Legend"},{"id":"ca47be34-8040-4b85-8b71-65ddd172dbd5","type":"LinearAxis"},{"id":"0312f7f8-b8c1-4b01-9057-b9c8f041fbaf","type":"LinearAxis"},{"id":"19e6d571-e1ba-4690-9f60-d5eab61234a1","type":"Grid"},{"id":"cb131644-9994-4f1e-9f6c-f0b582668c30","type":"Grid"}],"title":{"id":"768c5cdb-5baa-44c3-805b-d20b836db072","type":"Title"},"tool_events":{"id":"27fb7e3f-a042-4639-a319-ead0e3e99958","type":"ToolEvents"},"toolbar":{"id":"4bc8305c-888e-408d-88b8-e3a1e261f688","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"bc880b8b-6a2f-4355-a216-ae2e2b520de5","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"9694e772-1053-4087-aa28-360ef74fe6a7","type":"Range1d"}},"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"plot":{"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"},"tooltips":[["N Variants","@N_VARIANTS"],["Bin Start","@BIN_START"]]},"id":"81ce5789-0b3e-4cc6-aa61-f210c1c2a424","type":"HoverTool"},{"attributes":{"location":"top_left","plot":{"id":"a8564743-90b6-4b22-bb8f-b4e3091c2979","subtype":"Chart","type":"Plot"}},"id":"d58c34b1-dc84-4b5a-a7b4-dfe8312ca5fc","type":"Legend"},{"attributes":{},"id":"27fb7e3f-a042-4639-a319-ead0e3e99958","type":"ToolEvents"},{"attributes":{},"id":"1bd5eccb-6848-445d-a481-2ab555450e2c","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"051cbacf-3c46-4c06-a84b-e141d69620e9","type":"Circle"},{"attributes":{"axis_label":"BIN_START","formatter":{"id":"be8401fc-2450-4bed-9255-e3f500fed225","type":"BasicTic ...
